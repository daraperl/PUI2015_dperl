# %%
__author__ = 'dmp'
# %pylab inline
import numpy as np
import pylab as pl
import pandas as pd
#import kmseg
import sklearn.cluster
import geopandas as gp
from sklearn import mixture
from PIL import Image
from scipy.misc import imread
from scipy.cluster.vq import kmeans2
import json
import os
import zipfile #i am not giving it a name cause i intend to use it only once

kelly_colors_hex = [
    '#FFB300', # Vivid Yellow
    '#803E75', # Strong Purple
    '#FF6800', # Vivid Orange
    '#A6BDD7', # Very Light Blue
    '#C10020', # Vivid Red
    '#CEA262', # Grayish Yellow
    '#817066', # Medium Gray
    '#007D34', # Vivid Green
    '#F6768E', # Strong Purplish Pink
    '#00538A', # Strong Blue
    '#FF7A5C', # Strong Yellowish Pink
    '#53377A', # Strong Violet
    '#FF8E00', # Vivid Orange Yellow
    '#B32851', # Strong Purplish Red
    '#F4C800', # Vivid Greenish Yellow
    '#7F180D', # Strong Reddish Brown
    '#93AA00', # Vivid Yellowish Green
    '#593315', # Deep Yellowish Brown
    '#F13A13', # Vivid Reddish Orange
    '#232C16', # Dark Olive Green
    ]
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#Import the files and unzip them
#note all data files are in the same file as the ipython notebook
#add a year column to each data frame 
#create a new smaller data frame which includes just the zipcode, year, number of 
#establishments and the name of the zipcode area. 

zf94 = zipfile.ZipFile('zbp94totals.zip')
df94 = pd.read_csv(zf94.open('zbp94totals.zip'.replace('.zip','.txt')))
df94['year'] = '1994'
df94r1 = df94[['zip', 'year', 'est', 'name']]

zf95 = zipfile.ZipFile('zbp95totals.zip')
df95 = pd.read_csv(zf95.open('zbp95totals.zip'.replace('.zip','.txt')))
df95['year'] = '1995'
df95r1 = df95[['zip', 'year', 'est', 'name']]

zf96 = zipfile.ZipFile('zbp96totals.zip')
df96 = pd.read_csv(zf96.open('zbp96totals.zip'.replace('.zip','.txt')))
df96['year'] = '1996'
df96r1 = df96[['zip', 'year', 'est', 'name']]

zf97 = zipfile.ZipFile('zbp97totals.zip')
df97 = pd.read_csv(zf97.open('zbp97totals.zip'.replace('.zip','.txt')))
df97['year'] = '1997'
df97r1 = df97[['zip', 'year', 'est', 'name']]

zf98 = zipfile.ZipFile('zbp98totals.zip')
df98 = pd.read_csv(zf98.open('zbp98totals.zip'.replace('.zip','.txt')))
df98['year'] = '1998'
df98['zip'] = df98['ZIP']
df98['est'] = df98['EST']
df98['name'] = df98['NAME']
df98r1 = df98[['zip', 'year', 'est', 'name']]

zf99 = zipfile.ZipFile('zbp99totals.zip')
df99 = pd.read_csv(zf99.open('zbp99totals.zip'.replace('.zip','.txt')))
df99['year'] = '1999'
df99['zip'] = df99['ZIP']
df99['est'] = df99['EST']
df99['name'] = df99['NAME']
df99r1 = df99[['zip', 'year', 'est', 'name']]

zf00 = zipfile.ZipFile('zbp00totals.zip')
df00 = pd.read_csv(zf00.open('zbp00totals.zip'.replace('.zip','.txt')))
df00['year'] = '2000'
df00['zip'] = df00['ZIP']
df00['est'] = df00['EST']
df00['name'] = df00['NAME']
df00r1 = df00[['zip', 'year', 'est', 'name']]

zf01 = zipfile.ZipFile('zbp01totals.zip')
df01 = pd.read_csv(zf01.open('zbp01totals.zip'.replace('.zip','.txt')))
df01['year'] = '2001'
df01['zip'] = df01['ZIP']
df01['est'] = df01['EST']
df01['name'] = df01['NAME']
df01r1 = df01[['zip', 'year', 'est', 'name']]

zf02 = zipfile.ZipFile('zbp02totals.zip')
df02 = pd.read_csv(zf02.open('zbp02totals.zip'.replace('.zip','.txt')))
df02['year'] = '2002'
df02['zip'] = df02['ZIP']
df02['est'] = df02['EST']
df02['name'] = df02['NAME']
df02r1 = df02[['zip', 'year', 'est', 'name']]

zf03 = zipfile.ZipFile('zbp03totals.zip')
df03 = pd.read_csv(zf03.open('zbp03totals.zip'.replace('.zip','.txt')))
df03['year'] = '2003'
df03r1 = df03[['zip', 'year', 'est', 'name']]

zf04 = zipfile.ZipFile('zbp04totals.zip')
df04 = pd.read_csv(zf04.open('zbp04totals.zip'.replace('.zip','.txt')))
df04['year'] = '2004'
df04r1 = df04[['zip', 'year', 'est', 'name']]

zf05 = zipfile.ZipFile('zbp05totals.zip')
df05 = pd.read_csv(zf05.open('zbp05totals.zip'.replace('.zip','.txt')))
df05['year'] = '2005'
df05r1 = df05[['zip', 'year', 'est', 'name']]

zf06 = zipfile.ZipFile('zbp06totals.zip')
df06 = pd.read_csv(zf06.open('zbp06totals.zip'.replace('.zip','.txt')))
df06['year'] = '2006'
df06r1 = df06[['zip', 'year', 'est', 'name']]

zf07 = zipfile.ZipFile('zbp07totals.zip')
df07 = pd.read_csv(zf07.open('zbp07totals.zip'.replace('.zip','.txt')))
df07['year'] = '2007'
df07r1 = df07[['zip', 'year', 'est', 'name']]

zf08 = zipfile.ZipFile('zbp08totals.zip')
df08 = pd.read_csv(zf08.open('zbp08totals.zip'.replace('.zip','.txt')))
df08['year'] = '2008'
df08r1 = df08[['zip', 'year', 'est', 'name']]

zf09 = zipfile.ZipFile('zbp09totals.zip')
df09 = pd.read_csv(zf09.open('zbp09totals.zip'.replace('.zip','.txt')))
df09['year'] = '2009'
df09r1 = df09[['zip', 'year', 'est', 'name']]

zf10 = zipfile.ZipFile('zbp10totals.zip')
df10 = pd.read_csv(zf10.open('zbp10totals.zip'.replace('.zip','.txt')))
df10['year'] = '2010'
df10r1 = df10[['zip', 'year', 'est', 'name']]

zf11 = zipfile.ZipFile('zbp11totals.zip')
df11 = pd.read_csv(zf11.open('zbp11totals.zip'.replace('.zip','.txt')))
df11['year'] = '2011'
df11r1 = df11[['zip', 'year', 'est', 'name']]

zf12 = zipfile.ZipFile('zbp12totals.zip')
df12 = pd.read_csv(zf12.open('zbp12totals.zip'.replace('.zip','.txt')))
df12['year'] = '2012'
df12r1 = df12[['zip', 'year', 'est', 'name']]

zf13 = zipfile.ZipFile('zbp13totals.zip')
df13 = pd.read_csv(zf13.open('zbp13totals.zip'.replace('.zip','.txt')))
df13['year'] = '2013'
df13r1 = df13[['zip', 'year', 'est', 'name']]
#print df94r1.head()

# %%
#Import SHP File

zipdata = gp.read_file('nyc-zip-code-tabulation-areas-polygons.geojson')

# %%
# Array of NYC Zip Codes in strings not needed to be commented out
# nyczips = map(str, [10001, 10002, 10003, 10004, 10005, 10006, 10007, 10009, 10010, 
#                     10011, 10012, 10013, 10014, 10016, 10017, 10018, 10019, 10020, 
#                     10021, 10022, 10023, 10024, 10025, 10026, 10027, 10028, 10029, 
#                     10030, 10031, 10032, 10033, 10034, 10035, 10036, 10037, 10038, 
#                     10039, 10040, 10044, 10065, 10069, 10075, 10103, 10110, 10111, 
#                     10112, 10115, 10119, 10128, 10152, 10153, 10154, 10162, 10165, 
#concatenate all of the years of files

#This was something which I thought was necessary.  I now realize it is not helpful
#for this assignment
combined = pd.concat((df94r1, df95r1, df96r1, df97r1, df98r1, df99r1,
                     df00r1, df01r1, df02r1, df03r1, df04r1, df05r1, 
                     df06r1, df07r1, df08r1, df09r1, df10r1, df11r1, 
                     df12r1, df13r1), axis = 0)
combined.head()
# Out:
#     zip  year  est         name
# 0  1001  1994  439   Agawam, MA
# 1  1002  1994  450  Amherst, MA
# 2  1003  1994   10  Amherst, MA
# 3  1004  1994   47  Amherst, MA
# 4  1005  1994   92    Barre, MA

# %%
#filter for only NYC zipcodes in combined 

#This was something which I thought was necessary.  I now realize it is not helpful
#for this assignment
df = combined.loc[combined['zip'].isin(nyczips)]
#print df.head()
rownames(df) <- NULL
print df.loc[(df['year'] == '1994') & (df['zip'] == 10001)].est
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-3d8c43fef801> in <module>()
#       5 df = combined.loc[combined['zip'].isin(nyczips)]
#       6 #print df.head()
# ----> 7 rownames(df) <- NULL
#       8 print df.loc[(df['year'] == '1994') & (df['zip'] == 10001)].est
#
# NameError: name 'rownames' is not defined

# %%
data = {}
yearlydata = {}
for zipcode in nyczips:
    for year in years:
        yearlydata[year] = df.loc[(df['year'] == year) & (df['zip'] == zipcode)].est
        print yearlydata
    data[zipcode] = yearlydata
# Out:
# {'1994': 2966    6999
# Name: est, dtype: int64}
# {'1995': 3010    7088
# Name: est, dtype: int64, '1994': 2966    6999
# Name: est, dtype: int64}
# {'1995': 3010    7088
# Name: est, dtype: int64, '1994': 2966    6999
# Name: est, dtype: int64, '1996': 2998    7075
# Name: est, dtype: int64}
# {'1995': 3010    7088
# Name: est, dtype: int64, '1994': 2966    6999
# Name: est, dtype: int64, '1997': 3045    7154
# Name: est, dtype: int64, '1996': 2998    7075
# Name: est, dtype: int64}
# {'1998': 2987    7254
# Name: est, dtype: int64, '1995': 3010    7088
# Name: est, dtype: int64, '1994': 2966    6999
# Name: est, dtype: int64, '1997': 3045    7154
# Name: est, dtype: int64, '1996': 2998    7075
# Name: est, dtype: int64}
# {'1995': 3010    7088
# Name: est, dtype: int64, '1994': 2966    6999
# Name: est, dtype: int64, '1997': 3045    7154
# Name: est, dtype: int64, '1996': 2998    7075
# Name: est, dtype: int64, '1999': 3000    7233
# Name: est, dtype: int64, '1998': 2987    7254
# ...

# %%
print data
# Out:
# {10271: {'1995': 3544    32
# Name: est, dtype: int64, '1994': 3497    33
# Name: est, dtype: int64, '1997': 3583    38
# Name: est, dtype: int64, '1996': 3534    34
# Name: est, dtype: int64, '1999': 3531    38
# Name: est, dtype: int64, '1998': 3510    38
# Name: est, dtype: int64, '2002': 3495    37
# Name: est, dtype: int64, '2003': 3494    43
# Name: est, dtype: int64, '2000': 3540    39
# Name: est, dtype: int64, '2001': 3533    40
# Name: est, dtype: int64, '2006': 3502    49
# Name: est, dtype: int64, '2007': 3507    48
# Name: est, dtype: int64, '2004': 3507    43
# Name: est, dtype: int64, '2005': 3505    42
# Name: est, dtype: int64, '2008': 3446    49
# Name: est, dtype: int64, '2009': 3446    51
# Name: est, dtype: int64, '2011': 3436    46
# Name: est, dtype: int64, '2010': 3440    48
# Name: est, dtype: int64, '2013': 3418    40
# Name: est, dtype: int64, '2012': 3415    49
# Name: est, dtype: int64}, 10278: {'1995': 3544    32
# ...
